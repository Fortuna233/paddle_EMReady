# %%
import os
import re
from math import ceil
import numpy as np
from torchvision import models
import torch
import torch.nn as nn
from pytorch_msssim import ssim
from scunet import SCUNet
from utils import *
from torch import FloatTensor as FT
from torch.autograd import Variable as V
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# /home/tyche/miniconda3/envs/emready_env/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'libc10_cuda.so: cannot open shared object file: No such file or directory'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       6 import torch
#       7 import torch.nn as nn
# ----> 8 from pytorch_msssim import ssim
#       9 from scunet import SCUNet
#      10 from utils import *
#
# ModuleNotFoundError: No module named 'pytorch_msssim'

# %%
paramsFolder = "/data1/ryi/paddle_Emready/params"
params, n_epochs = get_all_files(paramsFolder)

def extract_number(s):
    match = re.search(r'\d+', s)
    return int(match.group()) if match else 0

params = sorted(params, key=extract_number)
len(params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 paramsFolder = "/data1/ryi/paddle_Emready/params"
# ----> 2 params, n_epochs = get_all_files(paramsFolder)
#       4 def extract_number(s):
#       5     match = re.search(r'\d+', s)
#
# NameError: name 'get_all_files' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# 设置中文字体显示
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

def create_sample_tensor(shape=(10, 20, 20), tensor_type='random'):
    """创建示例三维张量
    
    Args:
        shape: 张量形状，默认为(10, 20, 20)
        tensor_type: 张量类型，可选'random'(随机), 'cube'(立方体), 'sphere'(球体)
    
    Returns:
        三维numpy数组
    """
    if tensor_type == 'random':
        return np.random.rand(*shape)
    elif tensor_type == 'cube':
        tensor = np.zeros(shape)
        mid_x, mid_y, mid_z = shape[0]//2, shape[1]//2, shape[2]//2
        size = min(shape) // 3
        tensor[mid_x-size:mid_x+size, mid_y-size:mid_y+size, mid_z-size:mid_z+size] = 1
        return tensor
    elif tensor_type == 'sphere':
        tensor = np.zeros(shape)
        mid_x, mid_y, mid_z = shape[0]//2, shape[1]//2, shape[2]//2
        radius = min(shape) // 3
        for i in range(shape[0]):
            for j in range(shape[1]):
                for k in range(shape[2]):
                    if (i-mid_x)**2 + (j-mid_y)**2 + (k-mid_z)**2 <= radius**2:
                        tensor[i, j, k] = 1 - np.sqrt((i-mid_x)**2 + (j-mid_y)**2 + (k-mid_z)**2) / radius
        return tensor
    else:
        raise ValueError(f"不支持的张量类型: {tensor_type}")

def visualize_tensor_animation(tensor, axis=0, interval=500, cmap='viridis', title=None):
    """以动画形式展示三维张量的切片
    
    Args:
        tensor: 三维numpy数组
        axis: 切片轴，0,1,2分别代表x,y,z轴
        interval: 帧间隔(毫秒)
        cmap: 颜色映射
        title: 图表标题
    """
    # 确定切片数量和方向标签
    if axis == 0:
        slices = [tensor[i, :, :] for i in range(tensor.shape[0])]
        direction = "X轴方向"
    elif axis == 1:
        slices = [tensor[:, i, :] for i in range(tensor.shape[1])]
        direction = "Y轴方向"
    elif axis == 2:
        slices = [tensor[:, :, i] for i in range(tensor.shape[2])]
        direction = "Z轴方向"
    else:
        raise ValueError("axis参数必须是0,1,2中的一个")
    
    # 创建图形和轴
    fig, ax = plt.subplots(figsize=(8, 6))
    
    # 设置标题
    if title is None:
        title = f"三维张量切片动画 ({direction})"
    fig.suptitle(title, fontsize=16)
    
    # 显示第一个切片
    im = ax.imshow(slices[0], cmap=cmap)
    slice_text = ax.set_title(f"切片 {0}/{len(slices)-1}")
    
    # 添加颜色条
    cbar = fig.colorbar(im, ax=ax)
    cbar.set_label('数值')
    
    # 更新函数
    def update(frame):
        im.set_data(slices[frame])
        slice_text.set_text(f"切片 {frame}/{len(slices)-1}")
        return im, slice_text
    
    # 创建动画
    ani = FuncAnimation(fig, update, frames=len(slices), interval=interval, 
                        blit=True, repeat_delay=1000)
    
    plt.tight_layout()
    plt.show()
    
    return ani

def visualize_all_axes(tensor, interval=500, cmap='viridis', tensor_name=None):
    """沿三个轴分别展示张量切片动画"""
    axis_names = ['X', 'Y', 'Z']
    for i, axis_name in enumerate(axis_names):
        title = f"{tensor_name} 沿{axis_name}轴切片动画" if tensor_name else f"三维张量沿{axis_name}轴切片动画"
        visualize_tensor_animation(tensor, axis=i, interval=interval, cmap=cmap, title=title)

if __name__ == "__main__":
    # 创建示例张量
    random_tensor = create_sample_tensor((10, 20, 20), 'random')
    cube_tensor = create_sample_tensor((15, 15, 15), 'cube')
    sphere_tensor = create_sample_tensor((20, 20, 20), 'sphere')
    
    # 沿Z轴展示随机张量切片
    visualize_tensor_animation(random_tensor, axis=2, interval=300, 
                              cmap='plasma', title="随机张量Z轴切片动画")
    
    # 沿所有轴展示立方体张量
    visualize_all_axes(cube_tensor, interval=400, cmap='Blues', tensor_name="立方体")
    
    # 沿所有轴展示球体张量
    visualize_all_axes(sphere_tensor, interval=400, cmap='Reds', tensor_name="球体")
